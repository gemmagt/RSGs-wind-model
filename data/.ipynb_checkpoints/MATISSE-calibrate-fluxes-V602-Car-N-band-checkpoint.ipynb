# %% [markdown]
# # Flux calibration for MATISSE N band data
# This is the same as "MATISSE-calibrate-fluxes-V602-Car" file but for the N band. Please refer to that file for comments.
#
# This is an example for the target V602 Car, for the rest of the targets the script is the same changing the input
# files and MARCS models.
#
# IMPORTANT: change the url of the files location (now it is set to my personal computer, change to where your files are located.

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.utils.data import get_pkg_data_filename
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
#RAW CALIBRATOR
image_filec = get_pkg_data_filename('/home/ariggonz/Desktop/MATISSE-data-model-comp/V602-Car/CAL_N_V602-Car_HD91056_CALIB_RAWT_2023-01-20T08_07_01.6270.fits')#N-band calibrator

image_wavelength=fits.getdata(image_filec, ext=3)
image_flux=fits.getdata(image_filec, ext=8)
image_vis2=fits.getdata(image_filec, ext=4)

# %%
hdul = fits.open(image_filec)
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2023-01-31T10:40:20' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLTI-A1234'     / ESO <TEL>
# INSTRUME= 'MATISSE '           / Instrument used.
# OBJECT  = 'STD     '           / Original target.
# RA      =            157.21886 / [deg] 10:28:52.5 RA (J2000) pointing
# DEC     =            -64.17227 / [deg] -64:10:20.1 DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5
# EXPTIME =            0.0200088 / Integration time
# MJD-OBS =       59964.33821328 / 2023-01-20T08:07:01.6270
# DATE-OBS= '2023-01-20T08:07:01.6270' / Observing date
# UTC     =             29219.75 / [s] 08:06:59.750 UTC
# LST     =            40990.577 / [s] 11:23:10.577 LST
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# RADESYS = 'FK5     '           / Coordinate system
# DATAMD5 = '018d817d68860ee3e605c72f76f03803' / MD5 checksum
# PIPEFILE= 'CALIB_RAW_INT_0001.fits' / Filename of data product
# INSMODE = 'HYBRID  '
# CONTENT = 'OIFITS2 '
# ARCFILE = 'MATIS.2023-01-20T08:07:01.627.fits' / Archive File Name
# HIERARCH ESO OBS AIRM =     2. / Req. max. airmass
# HIERARCH ESO OBS AMBI TRANS = '3THN    ' / Req. sky transparency
# HIERARCH ESO OBS AOMODE = 'FULL_AO ' / Req. AO mode
# HIERARCH ESO OBS CONTAINER ID = 3379108 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE = 'C       ' / Scheduling container type
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-2.2' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 1808 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID =  3379122 / Observation block ID
# HIERARCH ESO OBS MOON DIST = 3 / Req. min. angular dist. from moon [deg]
# HIERARCH ESO OBS MOON FLI = 1. / Req. max. fractional lunar illum.
# HIERARCH ESO OBS NAME = 'CAL_N_V602-Car_HD91056' / OB name
# HIERARCH ESO OBS NTPL =      2 / Number of templates within OB
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 92794 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '110.23P1.001' / ESO program identification
# HIERARCH ESO OBS START = '2023-01-20T07:53:50' / OB start time
# HIERARCH ESO OBS TARG NAME = 'HD 91056' / OB target name
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO OBS TURB = '70%     ' / Req. Atmospheric Turbulence Category
# HIERARCH ESO OBS WATERVAPOUR = 30. / Req. water vapour
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO =    16 / Exposure number within template
# HIERARCH ESO TPL ID = 'MATISSE_hyb_obs_ft' / Template signature ID
# HIERARCH ESO TPL NAME = 'Celestial target observation with FT' / Template name
# HIERARCH ESO TPL NEXP =     40 / Number of exposures within template
# HIERARCH ESO TPL PRESEQ = 'MATISSE_obs.seq' / Sequencer script
# HIERARCH ESO TPL START = '2023-01-20T07:58:57' / TPL start time
# HIERARCH ESO TPL VERSION = '$Revision: 332467 $' / Version of the template
# HIERARCH ESO INS BCD1 ENC = 204 / [Enc] BCD device absolute position.
# HIERARCH ESO INS BCD1 ID = 'OUT     ' / BCD device unique ID.
# HIERARCH ESO INS BCD1 NAME = 'OUT     ' / BCD device name.
# HIERARCH ESO INS BCD1 NO =   1 / BCD device slot number.
# HIERARCH ESO INS BCD1 TYPE = 'NA      ' / BCD device element type.
# HIERARCH ESO INS BCD2 ENC = 202 / [Enc] BCD device absolute position.
# HIERARCH ESO INS BCD2 ID = 'OUT     ' / BCD device unique ID.
# HIERARCH ESO INS BCD2 NAME = 'OUT     ' / BCD device name.
# HIERARCH ESO INS BCD2 NO =   1 / BCD device slot number.
# HIERARCH ESO INS BCD2 TYPE = 'NA      ' / BCD device element type.
# HIERARCH ESO INS BCOP1 ENC = 24334 / [Enc] Absolute position of the BCD OPD adj.
# HIERARCH ESO INS BCOP1 POS = 24334 / [Enc] Position of the BCD OPD adj. device.
# HIERARCH ESO INS BCOP2 ENC = 24932 / [Enc] Absolute position of the BCD OPD adj.
# HIERARCH ESO INS BCOP2 POS = 24932 / [Enc] Position of the BCD OPD adj. device.
# HIERARCH ESO INS BCOP3 ENC = 29241 / [Enc] Absolute position of the BCD OPD adj.
# HIERARCH ESO INS BCOP3 POS = 29241 / [Enc] Position of the BCD OPD adj. device.
# HIERARCH ESO INS BCOP4 ENC = 36705 / [Enc] Absolute position of the BCD OPD adj.
# HIERARCH ESO INS BCOP4 POS = 36705 / [Enc] Position of the BCD OPD adj. device.
# HIERARCH ESO INS BCTP1 ENC = 29908 / [Enc] Absolute position of the BCD Tip.
# HIERARCH ESO INS BCTP1 POS = 29908 / [Enc] Position of the BCD Tip adj. device.
# HIERARCH ESO INS BCTP2 ENC = 29798 / [Enc] Absolute position of the BCD Tip.
# HIERARCH ESO INS BCTP2 POS = 29798 / [Enc] Position of the BCD Tip adj. device.
# HIERARCH ESO INS BCTP3 ENC = 40119 / [Enc] Absolute position of the BCD Tip.
# HIERARCH ESO INS BCTP3 POS = 40119 / [Enc] Position of the BCD Tip adj. device.
# HIERARCH ESO INS BCTP4 ENC = 32171 / [Enc] Absolute position of the BCD Tip.
# HIERARCH ESO INS BCTP4 POS = 32171 / [Enc] Position of the BCD Tip adj. device.
# HIERARCH ESO INS BCTT1 ENC = 32421 / [Enc] Absolute position of the BCD Tilt dev
# HIERARCH ESO INS BCTT1 POS = 32421 / [Enc] Position of the BCD Tilt adj. device.
# HIERARCH ESO INS BCTT2 ENC = 30403 / [Enc] Absolute position of the BCD Tilt dev
# HIERARCH ESO INS BCTT2 POS = 30403 / [Enc] Position of the BCD Tilt adj. device.
# HIERARCH ESO INS BCTT3 ENC = 23254 / [Enc] Absolute position of the BCD Tilt dev
# HIERARCH ESO INS BCTT3 POS = 23254 / [Enc] Position of the BCD Tilt adj. device.
# HIERARCH ESO INS BCTT4 ENC = 47565 / [Enc] Absolute position of the BCD Tilt dev
# HIERARCH ESO INS BCTT4 POS = 47565 / [Enc] Position of the BCD Tilt adj. device.
# HIERARCH ESO INS BSL1 ID = 'pshut1  ' / L&M BSL shutter ID.
# HIERARCH ESO INS BSL1 MODE = 'NORMAL  ' / Periodic/Fast Shutter to set if NORMAL
# HIERARCH ESO INS BSL1 NAME = 'fast shutter L1' / L&M BSL shutter name.
# HIERARCH ESO INS BSL1 ST =   T / L&M BSL shutter open.
# HIERARCH ESO INS BSL2 ID = 'bsl2    ' / L&M BSL shutter ID.
# HIERARCH ESO INS BSL2 NAME = 'fast shutter L2' / L&M BSL shutter name.
# HIERARCH ESO INS BSL2 ST =   T / L&M BSL shutter open.
# HIERARCH ESO INS BSL3 ID = 'bsl3    ' / L&M BSL shutter ID.
# HIERARCH ESO INS BSL3 NAME = 'fast shutter L3' / L&M BSL shutter name.
# HIERARCH ESO INS BSL3 ST =   T / L&M BSL shutter open.
# HIERARCH ESO INS BSL4 ID = 'bsl4    ' / L&M BSL shutter ID.
# HIERARCH ESO INS BSL4 NAME = 'fast shutter L4' / L&M BSL shutter name.
# HIERARCH ESO INS BSL4 ST =   T / L&M BSL shutter open.
# HIERARCH ESO INS BSN1 ID = 'bsn1    ' / N BSN shutter ID.
# HIERARCH ESO INS BSN1 MODE = 'NORMAL  ' / Periodic/Fast Shutter to set if NORMAL
# HIERARCH ESO INS BSN1 NAME = 'fast shutter N1' / N BSN shutter name.
# HIERARCH ESO INS BSN1 ST =   T / N BSN shutter open.
# HIERARCH ESO INS BSN2 ID = 'bsn2    ' / N BSN shutter ID.
# HIERARCH ESO INS BSN2 NAME = 'Shut N beam 2' / N BSN shutter name.
# HIERARCH ESO INS BSN2 ST =   T / N BSN shutter open.
# HIERARCH ESO INS BSN3 ID = 'bsn3    ' / N BSN shutter ID.
# HIERARCH ESO INS BSN3 NAME = 'Shut N beam 3' / N BSN shutter name.
# HIERARCH ESO INS BSN3 ST =   T / N BSN shutter open.
# HIERARCH ESO INS BSN4 ID = 'bsn4    ' / N BSN shutter ID.
# HIERARCH ESO INS BSN4 NAME = 'Shut N beam 4' / N BSN shutter name.
# HIERARCH ESO INS BSN4 ST =   T / N BSN shutter open.
# HIERARCH ESO INS CLLX1 ENC = 20007 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLX1 POS = 20007 / [Enc] Position of the L&M CUL lateral X adj
# HIERARCH ESO INS CLLX2 ENC = 22813 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLX2 POS = 22813 / [Enc] Position of the L&M CUL lateral X adj
# HIERARCH ESO INS CLLX3 ENC = 24159 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLX3 POS = 24159 / [Enc] Position of the L&M CUL lateral X adj
# HIERARCH ESO INS CLLX4 ENC = 18156 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLX4 POS = 18156 / [Enc] Position of the L&M CUL lateral X adj
# HIERARCH ESO INS CLLY1 ENC = 39937 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLY1 POS = 39937 / [Enc] Position of the L&M CUL lateral Y adj
# HIERARCH ESO INS CLLY2 ENC = 32165 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLY2 POS = 32165 / [Enc] Position of the L&M CUL lateral Y adj
# HIERARCH ESO INS CLLY3 ENC = 11122 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLY3 POS = 11122 / [Enc] Position of the L&M CUL lateral Y adj
# HIERARCH ESO INS CLLY4 ENC = 32436 / [Enc] Absolute position of the L&M CUL late
# HIERARCH ESO INS CLLY4 POS = 32436 / [Enc] Position of the L&M CUL lateral Y adj
# HIERARCH ESO INS CLTP1 ENC = 35198 / [Enc] Absolute position of the L&M CUL tip
# HIERARCH ESO INS CLTP1 POS = 35198 / [Enc] Position of the coalignment Tip adj.
# HIERARCH ESO INS CLTP2 ENC = 27315 / [Enc] Absolute position of the L&M CUL tip
# HIERARCH ESO INS CLTP2 POS = 27315 / [Enc] Position of the coalignment Tip adj.
# HIERARCH ESO INS CLTP3 ENC = 25828 / [Enc] Absolute position of the L&M CUL tip
# HIERARCH ESO INS CLTP3 POS = 25828 / [Enc] Position of the coalignment Tip adj.
# HIERARCH ESO INS CLTP4 ENC = 21861 / [Enc] Absolute position of the L&M CUL tip
# HIERARCH ESO INS CLTP4 POS = 21861 / [Enc] Position of the coalignment Tip adj.
# HIERARCH ESO INS CLTT1 ENC = 40963 / [Enc] Absolute position of the L&M coalignm
# HIERARCH ESO INS CLTT1 POS = 40963 / [Enc] Position of the coalignment Tilt adj.
# HIERARCH ESO INS CLTT2 ENC = 31047 / [Enc] Absolute position of the L&M coalignm
# HIERARCH ESO INS CLTT2 POS = 31047 / [Enc] Position of the coalignment Tilt adj.
# HIERARCH ESO INS CLTT3 ENC = 28267 / [Enc] Absolute position of the L&M coalignm
# HIERARCH ESO INS CLTT3 POS = 28267 / [Enc] Position of the coalignment Tilt adj.
# HIERARCH ESO INS CLTT4 ENC = 34572 / [Enc] Absolute position of the L&M coalignm
# HIERARCH ESO INS CLTT4 POS = 34572 / [Enc] Position of the coalignment Tilt adj.
# HIERARCH ESO INS CNLX1 ENC = 23520 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLX1 POS = 23520 / [Enc] Position of the N CUN lateral X adj.
# HIERARCH ESO INS CNLX2 ENC = 38009 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLX2 POS = 38009 / [Enc] Position of the N CUN lateral X adj.
# HIERARCH ESO INS CNLX3 ENC = 31323 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLX3 POS = 31323 / [Enc] Position of the N CUN lateral X adj.
# HIERARCH ESO INS CNLX4 ENC = 28309 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLX4 POS = 28309 / [Enc] Position of the N CUN lateral X adj.
# HIERARCH ESO INS CNLY1 ENC = 41220 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLY1 POS = 41220 / [Enc] Position of the N CUN lateral Y adj.
# HIERARCH ESO INS CNLY2 ENC = 29794 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLY2 POS = 29794 / [Enc] Position of the N CUN lateral Y adj.
# HIERARCH ESO INS CNLY3 ENC = 19553 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLY3 POS = 19553 / [Enc] Position of the N CUN lateral Y adj.
# HIERARCH ESO INS CNLY4 ENC = 31903 / [Enc] Absolute position of the N CUN latera
# HIERARCH ESO INS CNLY4 POS = 31903 / [Enc] Position of the N CUN lateral Y adj.
# HIERARCH ESO INS CNTP1 ENC = 33369 / [Enc] Absolute position of the N CUN tip ad
# HIERARCH ESO INS CNTP1 POS = 33369 / [Enc] Position of the N CUN tip adj. Device
# HIERARCH ESO INS CNTP2 ENC = 34230 / [Enc] Absolute position of the N CUN tip ad
# HIERARCH ESO INS CNTP2 POS = 34230 / [Enc] Position of the N CUN tip adj. Device
# HIERARCH ESO INS CNTP3 ENC = 33776 / [Enc] Absolute position of the N CUN tip ad
# HIERARCH ESO INS CNTP3 POS = 33776 / [Enc] Position of the N CUN tip adj. Device
# HIERARCH ESO INS CNTP4 ENC = 36595 / [Enc] Absolute position of the N CUN tip ad
# HIERARCH ESO INS CNTP4 POS = 36595 / [Enc] Position of the N CUN tip adj. Device
# HIERARCH ESO INS CNTT1 ENC = 34026 / [Enc] Absolute position of the N CUN tilt a
# HIERARCH ESO INS CNTT1 POS = 34026 / [Enc] Position of the CUN tilt adj. device.
# HIERARCH ESO INS CNTT2 ENC = 38511 / [Enc] Absolute position of the N CUN tilt a
# HIERARCH ESO INS CNTT2 POS = 38511 / [Enc] Position of the CUN tilt adj. device.
# HIERARCH ESO INS CNTT3 ENC = 34088 / [Enc] Absolute position of the N CUN tilt a
# HIERARCH ESO INS CNTT3 POS = 34088 / [Enc] Position of the CUN tilt adj. device.
# HIERARCH ESO INS CNTT4 ENC = 40996 / [Enc] Absolute position of the N CUN tilt a
# HIERARCH ESO INS CNTT4 POS = 40996 / [Enc] Position of the CUN tilt adj. device.
# HIERARCH ESO INS CPL1 ENC = 36367 / [Enc] Absolute position of the L&M CPL devic
# HIERARCH ESO INS CPL1 POS = 36367 / [Enc] Position of the L&M CPL device.
# HIERARCH ESO INS CPL2 ENC = 37730 / [Enc] Absolute position of the L&M CPL devic
# HIERARCH ESO INS CPL2 POS = 37730 / [Enc] Position of the L&M CPL device.
# HIERARCH ESO INS CPL3 ENC = 20970 / [Enc] Absolute position of the L&M CPL devic
# HIERARCH ESO INS CPL3 POS = 20970 / [Enc] Position of the L&M CPL device.
# HIERARCH ESO INS CPL4 ENC = 25969 / [Enc] Absolute position of the L&M CPL devic
# HIERARCH ESO INS CPL4 POS = 25969 / [Enc] Position of the L&M CPL device.
# HIERARCH ESO INS CPN1 ENC = 48012 / [Enc] Absolute position of the N CPN device.
# HIERARCH ESO INS CPN1 POS = 48012 / [Enc] Position of the N CPN device.
# HIERARCH ESO INS CPN2 ENC = 32155 / [Enc] Absolute position of the N CPN device.
# HIERARCH ESO INS CPN2 POS = 32155 / [Enc] Position of the N CPN device.
# HIERARCH ESO INS CPN3 ENC = 22837 / [Enc] Absolute position of the N CPN device.
# HIERARCH ESO INS CPN3 POS = 22837 / [Enc] Position of the N CPN device.
# HIERARCH ESO INS CPN4 ENC = 31545 / [Enc] Absolute position of the N CPN device.
# HIERARCH ESO INS CPN4 POS = 31545 / [Enc] Position of the N CPN device.
# HIERARCH ESO INS DATE = '2018-01-01' / Instrument release date (yyyy-mm-dd).
# HIERARCH ESO INS DIAPH ENC = 4003 / [Enc] Absolute position of the diaphragm uni
# HIERARCH ESO INS DIAPH POS = 28.1 / [mm] Absolute position of the diaphragm uni
# HIERARCH ESO INS DID1 = 'MATISSE_ICS-338677' / Data dictionary for INS.
# HIERARCH ESO INS DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INS.
# HIERARCH ESO INS DIL ENC = -580040 / [Enc] L&M DIL wheel absolute position.
# HIERARCH ESO INS DIL ID = 'MED     ' / L&M DIL  unique id.
# HIERARCH ESO INS DIL NAME = 'MED     ' / L&M DIL name.
# HIERARCH ESO INS DIL NO =    4 / L&M DIL wheel position index.
# HIERARCH ESO INS DIN ENC = -966942 / [Enc] N DIL wheel absolute position.
# HIERARCH ESO INS DIN ID = 'LOW     ' / N DIL unique id.
# HIERARCH ESO INS DIN NAME = 'LOW     ' / N DIL name.
# HIERARCH ESO INS DIN NO =    6 / N DIL wheel position index.
# HIERARCH ESO INS FFD ENC = 4800 / [Enc] Component absolute position.
# HIERARCH ESO INS FFD ID = 'PUP20   ' / FFD unique ID.
# HIERARCH ESO INS FFD NAME = 'PUP20   ' / FFD name.
# HIERARCH ESO INS FFD NO =    1 / Flat Field Device slot number.
# HIERARCH ESO INS FFD TYPE = 'MASK    ' / FFD element type.
# HIERARCH ESO INS FFDC ID = 'ffdc    ' / Flat Field Device ID.
# HIERARCH ESO INS FFDC INTPOWER = 0. / Flat Field Device intensity in perce
# HIERARCH ESO INS FFDC NAME = 'FFD control' / Flat Field Device name.
# HIERARCH ESO INS FFDC ST =   F / Flat Field Device activated.
# HIERARCH ESO INS FFDC STAT = 'OFF     ' / Flat Field Device position.
# HIERARCH ESO INS FIL ENC = -996010 / [Enc] L&M FIL wheel absolute position.
# HIERARCH ESO INS FIL ID = 'LM      ' / L&M FIL unique id.
# HIERARCH ESO INS FIL NAME = 'LM      ' / L&M FIL name.
# HIERARCH ESO INS FIL NO =    2 / L&M FIL wheel position index.
# HIERARCH ESO INS FIN ENC = 2406 / [Enc] N FIN wheel absolute position.
# HIERARCH ESO INS FIN ID = 'OPEN    ' / N FIN unique id.
# HIERARCH ESO INS FIN NAME = 'OPEN    ' / N FIN name.
# HIERARCH ESO INS FIN NO =    1 / Filter wheel position index.
# HIERARCH ESO INS ID = 'MATISSE/176642' / Instrument ID.
# HIERARCH ESO INS MODE = 'HYBRID  ' / Instrument mode used.
# HIERARCH ESO INS OML1 PERIOD = 4.074 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OML1 ST =   T / Start or stop the L&M OPD modulation.
# HIERARCH ESO INS OML1 START = '2023-01-20T08:01:53.00' / Start UTC time of the L
# HIERARCH ESO INS OML1 VOLT = 3.312683 / Move the L&M OML piezo manually in volt
# HIERARCH ESO INS OML2 PERIOD = 4.074 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OML2 ST =   T / Start or stop the L&M OPD modulation.
# HIERARCH ESO INS OML2 START = '2023-01-20T08:01:53.00' / Start UTC time of the L
# HIERARCH ESO INS OML2 VOLT = 3.79364 / Move the L&M OML piezo manually in volt
# HIERARCH ESO INS OML3 PERIOD = 4.074 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OML3 ST =   T / Start or stop the L&M OPD modulation.
# HIERARCH ESO INS OML3 START = '2023-01-20T08:01:53.00' / Start UTC time of the L
# HIERARCH ESO INS OML3 VOLT = 4.622803 / Move the L&M OML piezo manually in volt
# HIERARCH ESO INS OML4 PERIOD = 4.074 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OML4 ST =   T / Start or stop the L&M OPD modulation.
# HIERARCH ESO INS OML4 START = '2023-01-20T08:01:53.00' / Start UTC time of the L
# HIERARCH ESO INS OML4 VOLT = 4.82605 / Move the L&M OML piezo manually in volt
# HIERARCH ESO INS OMN1 PERIOD = 0.026 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OMN1 ST =   T / Start or stop the N OPD modulation.
# HIERARCH ESO INS OMN1 START = '2023-01-20T08:01:53.00' / Start UTC time of the N
# HIERARCH ESO INS OMN1 VOLT = 6.457825 / Move the N OMN piezo manually in volt un
# HIERARCH ESO INS OMN2 PERIOD = 0.026 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OMN2 ST =   T / Start or stop the N OPD modulation.
# HIERARCH ESO INS OMN2 START = '2023-01-20T08:01:53.00' / Start UTC time of the N
# HIERARCH ESO INS OMN2 VOLT = 4.86084 / Move the N OMN piezo manually in volt un
# HIERARCH ESO INS OMN3 PERIOD = 0.026 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OMN3 ST =   T / Start or stop the N OPD modulation.
# HIERARCH ESO INS OMN3 START = '2023-01-20T08:01:53.00' / Start UTC time of the N
# HIERARCH ESO INS OMN3 VOLT = 6.284485 / Move the N OMN piezo manually in volt un
# HIERARCH ESO INS OMN4 PERIOD = 0.026 / [sec] Timer output period of the L&M OPD
# HIERARCH ESO INS OMN4 ST =   T / Start or stop the N OPD modulation.
# HIERARCH ESO INS OMN4 START = '2023-01-20T08:01:53.00' / Start UTC time of the N
# HIERARCH ESO INS OMN4 VOLT = 8.028259 / Move the N OMN piezo manually in volt un
# HIERARCH ESO INS PIL ENC =   0 / [Enc] Component absolute position.
# HIERARCH ESO INS PIL ID = 'PHOTO   ' / PIL unique ID.
# HIERARCH ESO INS PIL NAME = 'PHOTO   ' / PIL name.
# HIERARCH ESO INS PIL NO =    1 / PIL slot number.
# HIERARCH ESO INS PIL TYPE = 'NA      ' / OPIL element type.
# HIERARCH ESO INS PIN ENC = 232000 / [Enc] Component absolute position.
# HIERARCH ESO INS PIN ID = 'INTER   ' / PIN unique ID.
# HIERARCH ESO INS PIN NAME = 'INTER   ' / PIN name.
# HIERARCH ESO INS PIN NO =    2 / PIN slot number.
# HIERARCH ESO INS PIN TYPE = 'NA      ' / PIN element type.
# HIERARCH ESO INS POL ENC = -4501 / L&M POL wheel absolute position [Enc].
# HIERARCH ESO INS POL ID = 'OPEN    ' / L&M POL unique id.
# HIERARCH ESO INS POL NAME = 'OPEN    ' / L&M POL name.
# HIERARCH ESO INS POL NO =    1 / L&M POL wheel position index.
# HIERARCH ESO INS PON ENC = 16756 / N PON wheel absolute position [Enc].
# HIERARCH ESO INS PON ID = 'OPEN    ' / N PON unique id.
# HIERARCH ESO INS PON NAME = 'OPEN    ' / N PON name.
# HIERARCH ESO INS PON NO =    1 / Filter wheel position index.
# HIERARCH ESO INS SENS1 STAT = 128 / Prevacuum Pressure Gauge Status.
# HIERARCH ESO INS SENS10 VAL = 93.08 / [K] 80K radiation shield top Value.
# HIERARCH ESO INS SENS100 STAT = 8228 / Turbo Molecular Pump Status.
# HIERARCH ESO INS SENS101 STAT = 8708 / Vacuum Insulating Valve Status.
# HIERARCH ESO INS SENS102 STAT = 8196 / Re-pressuration Valve Status.
# HIERARCH ESO INS SENS103 STAT = F / LN2 tank level exceeded alarm.
# HIERARCH ESO INS SENS104 STAT = F / Pressure in Prevacuum line is OK.
# HIERARCH ESO INS SENS105 STAT = F / Turbo Molecular pump running nominal.
# HIERARCH ESO INS SENS106 STAT = F / Dry Nitrogen line is connected.
# HIERARCH ESO INS SENS107 STAT = T / Cabinet cooling flow rate OK.
# HIERARCH ESO INS SENS108 STAT = 8192 / COB Warmup Heater Status.
# HIERARCH ESO INS SENS109 STAT = 8192 / LN2 Vessel Warmup Heater Status.
# HIERARCH ESO INS SENS11 STAT = 1 / 80K radiation shield bot Status.
# HIERARCH ESO INS SENS110 STAT = 8192 / Sorption Pump Heater Status.
# HIERARCH ESO INS SENS111 STAT = 99 / Pulsetube Compressor Status.
# HIERARCH ESO INS SENS112 STAT = 128 / Voltage Monitoring - COB Heater alarm.
# HIERARCH ESO INS SENS113 STAT = 128 / Current Monitoring - COB Heater alarm.
# HIERARCH ESO INS SENS114 STAT = 128 / Voltage Monitoring - LN2 Vessel Heater ala
# HIERARCH ESO INS SENS115 STAT = 128 / Current Monitoring - LN2 Vessel Heater .
# HIERARCH ESO INS SENS116 STAT = 128 / Prevacuum Pressure Gauge Status.
# HIERARCH ESO INS SENS117 VAL = 5.23 / [mbar] Prevacuum Pressure Gauge Value.
# HIERARCH ESO INS SENS118 STAT = 65 / Cryostat Pressure Gauge 1 Status.
# HIERARCH ESO INS SENS119 VAL = 3.22E-07 / [mbar] Cryostat Pressure Gauge 1 Value
# HIERARCH ESO INS SENS12 VAL = 84.03 / [K] 80K radiation shield bot Value.
# HIERARCH ESO INS SENS120 STAT = 1 / Cryostat Pressure Gauge 2 Status.
# HIERARCH ESO INS SENS121 VAL = 2.66E-07 / [mbar] Cryostat Pressure Gauge 2 Value
# HIERARCH ESO INS SENS122 STAT = 128 / Turbomolecular pump speed Status.
# HIERARCH ESO INS SENS123 VAL = 0. / [rpm] Turbomolecular pump speed Value.
# HIERARCH ESO INS SENS124 STAT = 1 / 80K radiation shield top Status.
# HIERARCH ESO INS SENS125 VAL = 93.99 / [K] 80K radiation shield top Value.
# HIERARCH ESO INS SENS126 STAT = 1 / 80K radiation shield bot Status.
# HIERARCH ESO INS SENS127 VAL = 83.15 / [K] 80K radiation shield bot Value.
# HIERARCH ESO INS SENS128 STAT = 1 / spatial filter actuator Status.
# HIERARCH ESO INS SENS129 VAL = 30.74 / [K] spatial filter actuator Value.
# HIERARCH ESO INS SENS13 STAT = 1 / spatial filter actuator Status.
# HIERARCH ESO INS SENS130 STAT = 1 / backbone, near cold head Status.
# HIERARCH ESO INS SENS131 VAL = 30.53 / [K] backbone, near cold head Value.
# HIERARCH ESO INS SENS132 STAT = 1 / wheel box actuator Status.
# HIERARCH ESO INS SENS133 VAL = 31.27 / [K] wheel box actuator Value.
# HIERARCH ESO INS SENS134 STAT = 1 / camera ZnSe lens Status.
# HIERARCH ESO INS SENS135 VAL = 30.91 / [K] camera ZnSe lens Value.
# HIERARCH ESO INS SENS136 STAT = '1       ' / camera ZnSe lens (redundant) Status
# HIERARCH ESO INS SENS137 VAL = 30.9 / [K] camera ZnSe lens (redundant) Value.
# HIERARCH ESO INS SENS138 STAT = 1 / BSB - near photo/interferometric act. Status
# HIERARCH ESO INS SENS139 VAL = 31.61 / [K] BSB - near photo/interferometric act.
# HIERARCH ESO INS SENS14 VAL = 31.4 / [K] spatial filter actuator Value.
# HIERARCH ESO INS SENS140 STAT = 1 / Detector operation temperature Status.
# HIERARCH ESO INS SENS141 VAL = 8. / [K] Detector operation temperature Value.
# HIERARCH ESO INS SENS142 STAT = 1 / Detector warmup heater sensor Status.
# HIERARCH ESO INS SENS143 VAL = 3.28 / [K] Detector warmup heater sensor Value.
# HIERARCH ESO INS SENS144 STAT = 1 / Sorption pump temperature Status.
# HIERARCH ESO INS SENS145 VAL = 85.32 / [K] Sorption pump temperature Value.
# HIERARCH ESO INS SENS146 STAT = 1 / Ambient temperature Status.
# HIERARCH ESO INS SENS147 VAL = 16.97 / [C] Ambient temperature Value.
# HIERARCH ESO INS SENS148 STAT = 1 / Cabinet inside top temperature Status.
# HIERARCH ESO INS SENS149 VAL = 18.21 / [C] Cabinet inside top temperature Value.
# HIERARCH ESO INS SENS15 STAT = 1 / backbone, near cold head Status.
# HIERARCH ESO INS SENS150 STAT = 1 / Cabinet inside bottom temperature Status.
# HIERARCH ESO INS SENS151 VAL = 15.79 / [C] Cabinet inside bottom temperature Val
# HIERARCH ESO INS SENS152 STAT = 1 / PLC unit temperature Status.
# HIERARCH ESO INS SENS153 VAL = 19.79 / [C] PLC unit temperature Value.
# HIERARCH ESO INS SENS154 STAT = 1 / Warmup heater unit temperature Status.
# HIERARCH ESO INS SENS155 VAL = 17.9 / [C] Warmup heater unit temperature Value.
# HIERARCH ESO INS SENS156 STAT = 1 / Cabinet coolant supply temperature Status.
# HIERARCH ESO INS SENS157 VAL = 8.09 / [C] Cabinet coolant supply temperature Val
# HIERARCH ESO INS SENS158 STAT = 1 / Cabinet coolant return temperature Status.
# HIERARCH ESO INS SENS159 VAL = 10.28 / [C] Cabinet coolant return temperature Va
# HIERARCH ESO INS SENS16 VAL = 31.05 / [K] backbone, near cold head Value.
# HIERARCH ESO INS SENS160 VAL = 71.86 / [%] Cabinet cooling valve commanded posit
# HIERARCH ESO INS SENS161 STAT = 515 / LN2 tank level detection - empty Status.
# HIERARCH ESO INS SENS162 VAL = 75.31 / [%] LN2 tank level detection - empty Valu
# HIERARCH ESO INS SENS163 STAT = F / LM-band cryostat - CAS alarm active.
# HIERARCH ESO INS SENS164 STAT = F / LM-band cryostat - collective alarm active.
# HIERARCH ESO INS SENS165 STAT = F / Evacuation Sequence alarm.
# HIERARCH ESO INS SENS166 STAT = F / SP regeneration Sequence alarm.
# HIERARCH ESO INS SENS167 STAT = F / cooldown sequence alarm.
# HIERARCH ESO INS SENS168 STAT = F / warmup sequence alarm.
# HIERARCH ESO INS SENS169 STAT = F / Cabinet Coolant Flow low alarm.
# HIERARCH ESO INS SENS17 STAT = 1 / wheel box actuator Status.
# HIERARCH ESO INS SENS170 STAT = F / He-compressor coolant flow low alarm.
# HIERARCH ESO INS SENS171 STAT = F / He-compressor cabinet temperature alarm.
# HIERARCH ESO INS SENS172 STAT = F / PSU Vacuum System alarm.
# HIERARCH ESO INS SENS173 STAT = F / Roughing Pump alarm.
# HIERARCH ESO INS SENS174 STAT = F / Turbomolecular Pump alarm.
# HIERARCH ESO INS SENS175 STAT = F / Vacuum Insulating Valve alarm.
# HIERARCH ESO INS SENS176 STAT = F / Re-PressurizationValve alarm.
# HIERARCH ESO INS SENS177 STAT = F / PSU Warm-Up Heaters alarm.
# HIERARCH ESO INS SENS178 STAT = F / Cold Bench Heater alarm.
# HIERARCH ESO INS SENS179 STAT = F / LN2 Vessel Heater alarm.
# HIERARCH ESO INS SENS18 VAL = 32.06 / [K] wheel box actuator Value.
# HIERARCH ESO INS SENS180 STAT = F / Sorption Pump Heater alarm.
# HIERARCH ESO INS SENS181 STAT = F / Detector Warm-Up Heater alarm.
# HIERARCH ESO INS SENS182 STAT = F / Detector control heater alarm.
# HIERARCH ESO INS SENS183 STAT = F / Detector preamplifier heater alarm.
# HIERARCH ESO INS SENS184 STAT = F / Pulsetube Cooler alarm.
# HIERARCH ESO INS SENS185 STAT = 3 / Operation mode.
# HIERARCH ESO INS SENS186 STAT = 1 / Evacuation sequence step.
# HIERARCH ESO INS SENS187 STAT = 1 / SP regeneration sequence step.
# HIERARCH ESO INS SENS188 STAT = 1 / Warm-up sequence step.
# HIERARCH ESO INS SENS189 VAL = 0. / [%] percentage the DW heater is running.
# HIERARCH ESO INS SENS19 STAT = 1 / camera ZnSe lens Status.
# HIERARCH ESO INS SENS190 VAL = 0. / [%] percentage the COB heater is running.
# HIERARCH ESO INS SENS191 VAL = 0. / [%] percentage the LN heater is running.
# HIERARCH ESO INS SENS192 VAL = 36.2 / [%] percentage the DET heater is running.
# HIERARCH ESO INS SENS193 STAT = 1 / current range of the DET heater.
# HIERARCH ESO INS SENS194 STAT = F / Evacuation sequence.
# HIERARCH ESO INS SENS195 STAT = F / SP regeneration sequence.
# HIERARCH ESO INS SENS196 STAT = F / Warmup sequence.
# HIERARCH ESO INS SENS197 STAT = F / Cryostat is warm.
# HIERARCH ESO INS SENS198 STAT = F / Cryostat is cold.
# HIERARCH ESO INS SENS199 STAT = F / Cryostat T >= Warmup setpoint.
# HIERARCH ESO INS SENS2 VAL = 76.6 / [mbar] Prevacuum Pressure Gauge Value.
# HIERARCH ESO INS SENS20 VAL = 31.82 / [K] camera ZnSe lens Value.
# HIERARCH ESO INS SENS200 STAT = F / Sorption Pump reached reg. temp T >= Reg. SP
# HIERARCH ESO INS SENS201 STAT = F / RMC motor control interlock.
# HIERARCH ESO INS SENS202 STAT = F / Cryostat pressure is atmospheric >= 7.0E2mba
# HIERARCH ESO INS SENS203 STAT = F / Cryostat pressure is <= 1 mbar.
# HIERARCH ESO INS SENS204 STAT = F / Cryostat pressure is <= 1E-2 mbar.
# HIERARCH ESO INS SENS205 STAT = F / Cryostat pressure is <= 1E-3 mbar.
# HIERARCH ESO INS SENS206 STAT = F / Pressure Gauge VG2 is active.
# HIERARCH ESO INS SENS207 STAT = F / Pressure Gauge VG3 is active.
# HIERARCH ESO INS SENS208 STAT = F / PSU Vacuum System Pump on/off.
# HIERARCH ESO INS SENS209 STAT = F / PSU Heater Status on/off.
# HIERARCH ESO INS SENS21 STAT = 1 / camera ZnSe lens (redundant) Status.
# HIERARCH ESO INS SENS210 STAT = 8196 / Roughing Vacuum Pump Status.
# HIERARCH ESO INS SENS211 STAT = 8228 / Turbo Molecular Pump Status.
# HIERARCH ESO INS SENS212 STAT = 8708 / Vacuum Insulating Valve Status.
# HIERARCH ESO INS SENS213 STAT = 8196 / Re-pressuration Valve Status.
# HIERARCH ESO INS SENS214 STAT = F / LN2 tank level exceeded alarm.
# HIERARCH ESO INS SENS215 STAT = F / Pressure in Prevacuum line is OK.
# HIERARCH ESO INS SENS216 STAT = F / Turbo Molecular pump running nominal.
# HIERARCH ESO INS SENS217 STAT = F / Dry Nitrogen line is connected.
# HIERARCH ESO INS SENS218 STAT = T / Cabinet cooling flow rate OK.
# HIERARCH ESO INS SENS219 STAT = 8192 / COB Warmup Heater Status.
# HIERARCH ESO INS SENS22 VAL = 31.87 / [K] camera ZnSe lens (redundant) Value.
# HIERARCH ESO INS SENS220 STAT = 8192 / LN2 Vessel Warmup Heater Status.
# HIERARCH ESO INS SENS221 STAT = 8192 / Sorption Pump Heater Status.
# HIERARCH ESO INS SENS222 STAT = 99 / Pulsetube Compressor Status.
# HIERARCH ESO INS SENS223 STAT = 128 / Voltage Monitoring - COB Heater alarm.
# HIERARCH ESO INS SENS224 STAT = 128 / Current Monitoring - COB Heater alarm.
# HIERARCH ESO INS SENS225 STAT = 128 / Voltage Monitoring - LN2 Vessel Heater ala
# HIERARCH ESO INS SENS226 STAT = 128 / Current Monitoring - LN2 Vessel Heater.
# HIERARCH ESO INS SENS227 STAT = T / Cabinet Coolant Flow Switch OK.
# HIERARCH ESO INS SENS228 STAT = T / Flow rate NGC L OK.
# HIERARCH ESO INS SENS229 STAT = T / Flow rate NGC N OK.
# HIERARCH ESO INS SENS23 STAT = 1 / BSB - near photo/interferometric act. Status.
# HIERARCH ESO INS SENS230 STAT = T / Flow rate IR Lamp OK.
# HIERARCH ESO INS SENS231 STAT = F / WOP - CAS alarm active.
# HIERARCH ESO INS SENS232 STAT = F / WOP - collective alarm active.
# HIERARCH ESO INS SENS233 STAT = F / Cabinet Coolant Flow Low Alarm.
# HIERARCH ESO INS SENS234 STAT = F / Flow rate NGC L Low Alarm.
# HIERARCH ESO INS SENS235 STAT = F / Flow rate NGC N Low Alarm.
# HIERARCH ESO INS SENS236 STAT = F / Flow rate IR Lamp Low Alarm.
# HIERARCH ESO INS SENS237 STAT = 4 / PSU Cabinet Equipement Status.
# HIERARCH ESO INS SENS238 STAT = 8200 / Laser Module Status.
# HIERARCH ESO INS SENS239 STAT = 1 / SOS Ambient temperature Status.
# HIERARCH ESO INS SENS24 VAL = 32.18 / [K] BSB - near photo/interferometric act.
# HIERARCH ESO INS SENS240 VAL = 14.98 / [C] SOS Ambient temperature Value.
# HIERARCH ESO INS SENS241 STAT = 1 / CPL Ambient temperature Status.
# HIERARCH ESO INS SENS242 VAL = 15.01 / [C] CPL Ambient temperature Value.
# HIERARCH ESO INS SENS243 STAT = 1 / CPN Ambient temperature Status.
# HIERARCH ESO INS SENS244 VAL = 14.88 / [C] CPN Ambient temperature Value.
# HIERARCH ESO INS SENS245 STAT = 1 / ARC Ambient temperature Status.
# HIERARCH ESO INS SENS246 VAL = 13.91 / [C] ARC Ambient temperature Value.
# HIERARCH ESO INS SENS247 STAT = 1 / ARC FFD temperature Status.
# HIERARCH ESO INS SENS248 VAL = 16.77 / [C] ARC FFD temperature Value.
# HIERARCH ESO INS SENS249 STAT = 65 / ARC box temperature Status.
# HIERARCH ESO INS SENS25 STAT = 1 / Detector operation temperature Status.
# HIERARCH ESO INS SENS250 VAL = 8.25 / [C] ARC box temperature Value.
# HIERARCH ESO INS SENS251 STAT = 1 / ARC screen temperature Status.
# HIERARCH ESO INS SENS252 VAL = 8.21 / [C] ARC screen temperature Value.
# HIERARCH ESO INS SENS253 STAT = 1 / Coolant supply temperature Status.
# HIERARCH ESO INS SENS254 VAL = 7.62 / [C] Coolant temperature Value.
# HIERARCH ESO INS SENS255 STAT = 1 / Coolant return temperature Status.
# HIERARCH ESO INS SENS256 VAL = 8.35 / [C] Coolant return temperature Value.
# HIERARCH ESO INS SENS257 STAT = 1 / Cabinet ambient temperature Status.
# HIERARCH ESO INS SENS258 VAL = 17.53 / [C] Cabinet ambient temperature Value.
# HIERARCH ESO INS SENS259 STAT = 1 / Cabinet inside top temperature Status.
# HIERARCH ESO INS SENS26 VAL = 40.007 / [K] Detector operation temperature Value.
# HIERARCH ESO INS SENS260 VAL = 19.45 / [C] Cabinet inside top temperature Value.
# HIERARCH ESO INS SENS261 STAT = 1 / Cabinet inside bottom temperature Status.
# HIERARCH ESO INS SENS262 VAL = 15.62 / [C] Cabinet inside bottom temperature Val
# HIERARCH ESO INS SENS263 STAT = 1 / PLC temperature Status.
# HIERARCH ESO INS SENS264 VAL = 21.07 / [C] PLC temperature Value.
# HIERARCH ESO INS SENS265 STAT = 1 / Cabinet Coolant Supply temperature Status.
# HIERARCH ESO INS SENS266 VAL = 8.15 / [C] Cabinet Coolant Supply temperature Val
# HIERARCH ESO INS SENS267 STAT = 1 / Cabinet Coolant Return temperature Status.
# HIERARCH ESO INS SENS268 VAL = 11.64 / [C] Cabinet Coolant Return temperature Va
# HIERARCH ESO INS SENS269 STAT = 1 / Motion Control Unit 1 temperature Status.
# HIERARCH ESO INS SENS27 STAT = 1 / Detector preamp temperature (H2RG only) Statu
# HIERARCH ESO INS SENS270 VAL = 21.61 / [C] Motion Control Unit 1 temperature Val
# HIERARCH ESO INS SENS271 STAT = 1 / Motion Control Unit 2 temperature Status.
# HIERARCH ESO INS SENS272 VAL = 22.14 / [C] Motion Control Unit 2 temperature Val
# HIERARCH ESO INS SENS273 STAT = 1 / Motion Control Unit 3 temperature Status.
# HIERARCH ESO INS SENS274 VAL = 20.87 / [C] Motion Control Unit 3 temperature Val
# HIERARCH ESO INS SENS275 STAT = 1 / Motion Control Unit 4 temperature Status.
# HIERARCH ESO INS SENS276 VAL = 21.49 / [C] Motion Control Unit 4 temperature Val
# HIERARCH ESO INS SENS277 STAT = 1 / SCP1 supply temperature Status.
# HIERARCH ESO INS SENS278 VAL = 6.81 / [C] SCP1 supply temperature Value.
# HIERARCH ESO INS SENS279 STAT = 1 / SCP1 return temperature Status.
# HIERARCH ESO INS SENS28 VAL = 83.674 / [K] Detector preamp temperature (H2RG onl
# HIERARCH ESO INS SENS280 VAL = 19.47 / [C] SCP1 return temperature Value.
# HIERARCH ESO INS SENS281 STAT = 1 / SCP2 supply temperature Status.
# HIERARCH ESO INS SENS282 VAL = 7.85 / [C] SCP2 supply temperature Value.
# HIERARCH ESO INS SENS283 STAT = 1 / SCP2 return temperature Status.
# HIERARCH ESO INS SENS284 VAL = 10.42 / [C] SCP2 return temperature Value.
# HIERARCH ESO INS SENS285 VAL = 62.83 / [%] Cabinet cooling valve commanded posit
# HIERARCH ESO INS SENS286 STAT = 4 / IR Lamp housing cooling valve Status.
# HIERARCH ESO INS SENS287 VAL = 0. / [%] IR Lamp housing cooling valve commande
# HIERARCH ESO INS SENS288 VAL = 0. / [%] FFDC PID Loop manipulated variable.
# HIERARCH ESO INS SENS29 STAT = 1 / Detector warmup heater sensor Status.
# HIERARCH ESO INS SENS3 STAT = 65 / Cryostat Pressure Gauge 1 Status.
# HIERARCH ESO INS SENS30 VAL = 4.01 / [K] Detector warmup heater sensor Value.
# HIERARCH ESO INS SENS31 STAT = 1 / Sorption pump temperature Status.
# HIERARCH ESO INS SENS32 VAL = 85.01 / [K] Sorption pump temperature Value.
# HIERARCH ESO INS SENS33 STAT = 1 / Ambient temperature Status.
# HIERARCH ESO INS SENS34 VAL = 17.21 / [C] Ambient temperature Value.
# HIERARCH ESO INS SENS35 STAT = 1 / Cabinet inside top temperature Status.
# HIERARCH ESO INS SENS36 VAL = 18.14 / [C] Cabinet inside top temperature Value.
# HIERARCH ESO INS SENS37 STAT = 1 / Cabinet inside bottom temperature Status.
# HIERARCH ESO INS SENS38 VAL = 16.04 / [C] Cabinet inside bottom temperature Valu
# HIERARCH ESO INS SENS39 STAT = 1 / PLC unit temperature Status.
# HIERARCH ESO INS SENS4 VAL = 1.22E-07 / [mbar] Cryostat Pressure Gauge 1 Value.
# HIERARCH ESO INS SENS40 VAL = 19.11 / [C] PLC unit temperature Value.
# HIERARCH ESO INS SENS41 STAT = 1 / Warmup heater unit temperature Status.
# HIERARCH ESO INS SENS42 VAL = 18.2 / [C] Warmup heater unit temperature Value.
# HIERARCH ESO INS SENS43 STAT = 1 / Cabinet coolant supply temperature Status.
# HIERARCH ESO INS SENS44 VAL = 8.25 / [C] Cabinet coolant supply temperature Valu
# HIERARCH ESO INS SENS45 STAT = 1 / Cabinet coolant return temperature Status.
# HIERARCH ESO INS SENS46 VAL = 8.72 / [C] Cabinet coolant return temperature Valu
# HIERARCH ESO INS SENS47 VAL = 41.87 / [%] Cabinet cooling valve commanded positi
# HIERARCH ESO INS SENS48 STAT = 515 / LN2 tank level detection - empty Status.
# HIERARCH ESO INS SENS49 VAL = 75.62 / [%] LN2 tank level detection - empty Value
# HIERARCH ESO INS SENS5 STAT = 1 / Cryostat Pressure Gauge 2 Status.
# HIERARCH ESO INS SENS50 STAT = F / LM-band cryostat - CAS alarm active.
# HIERARCH ESO INS SENS51 STAT = F / LM-band cryostat - collective alarm active.
# HIERARCH ESO INS SENS52 STAT = F / Evacuation Sequence alarm.
# HIERARCH ESO INS SENS53 STAT = F / SP regeneration Sequence alarm.
# HIERARCH ESO INS SENS54 STAT = F / cooldown sequence alarm.
# HIERARCH ESO INS SENS55 STAT = F / warmup sequence alarm.
# HIERARCH ESO INS SENS56 STAT = F / Cabinet Coolant Flow low alarm.
# HIERARCH ESO INS SENS57 STAT = F / He-compressor coolant flow low alarm.
# HIERARCH ESO INS SENS58 STAT = F / He-compressor cabinet temperature alarm.
# HIERARCH ESO INS SENS59 STAT = F / PSU Vacuum System alarm.
# HIERARCH ESO INS SENS6 VAL = 1.08E-07 / [mbar] Cryostat Pressure Gauge 2 Value.
# HIERARCH ESO INS SENS60 STAT = F / Roughing Pump alarm.
# HIERARCH ESO INS SENS61 STAT = F / Turbomolecular Pump alarm.
# HIERARCH ESO INS SENS62 STAT = F / Vacuum Insulating Valve alarm.
# HIERARCH ESO INS SENS63 STAT = F / Re-PressurizationValve alarm.
# HIERARCH ESO INS SENS64 STAT = F / PSU Warm-Up Heaters alarm.
# HIERARCH ESO INS SENS65 STAT = F / Cold Bench Heater alarm.
# HIERARCH ESO INS SENS66 STAT = F / LN2 Vessel Heater alarm.
# HIERARCH ESO INS SENS67 STAT = F / Sorption Pump Heater alarm.
# HIERARCH ESO INS SENS68 STAT = F / Detector Warm-Up Heater alarm.
# HIERARCH ESO INS SENS69 STAT = F / Detector control heater alarm.
# HIERARCH ESO INS SENS7 STAT = 128 / Turbomolecular pump speed Status.
# HIERARCH ESO INS SENS70 STAT = F / Detector preamplifier heater alarm.
# HIERARCH ESO INS SENS71 STAT = F / Pulsetube Cooler alarm.
# HIERARCH ESO INS SENS72 STAT = 3 / Operation mode.
# HIERARCH ESO INS SENS73 STAT = 1 / Evacuation sequence step.
# HIERARCH ESO INS SENS74 STAT = 1 / SP regeneration sequence step.
# HIERARCH ESO INS SENS75 STAT = 1 / Warm-up sequence step.
# HIERARCH ESO INS SENS76 VAL = 0. / [%] percentage the DW heater is running.
# HIERARCH ESO INS SENS77 VAL = 0. / [%] percentage the COB heater is running.
# HIERARCH ESO INS SENS78 VAL = 0. / [%] percentage the LN heater is running.
# HIERARCH ESO INS SENS79 VAL = 18.6 / [%] percentage the DET heater is running.
# HIERARCH ESO INS SENS8 VAL = 0. / [rpm] Turbomolecular pump speed Value.
# HIERARCH ESO INS SENS80 STAT = 1 / Current range of the DET heater.
# HIERARCH ESO INS SENS81 VAL = 0. / [%] percentage the DPT heater is running.
# HIERARCH ESO INS SENS82 STAT = 1 / Current range of the DPT heater.
# HIERARCH ESO INS SENS83 STAT = F / Evacuation sequence.
# HIERARCH ESO INS SENS84 STAT = F / SP regeneration sequence.
# HIERARCH ESO INS SENS85 STAT = F / Warmup sequence.
# HIERARCH ESO INS SENS86 STAT = F / Cryostat is warm.
# HIERARCH ESO INS SENS87 STAT = F / Cryostat is cold.
# HIERARCH ESO INS SENS88 STAT = F / Cryostat T >= Warmup setpoint.
# HIERARCH ESO INS SENS89 STAT = F / Sorption Pump reached reg. temp T >= Reg. SP
# HIERARCH ESO INS SENS9 STAT = 1 / 80K radiation shield top Status.
# HIERARCH ESO INS SENS90 STAT = F / RMC motor control interlock.
# HIERARCH ESO INS SENS91 STAT = F / Cryostat pressure is atmospheric >= 7.0E2mbar
# HIERARCH ESO INS SENS92 STAT = F / Cryostat pressure is <= 1 mbar.
# HIERARCH ESO INS SENS93 STAT = F / Cryostat pressure is <= 1E-2 mbar.
# HIERARCH ESO INS SENS94 STAT = F / Cryostat pressure is <= 1E-3 mbar.
# HIERARCH ESO INS SENS95 STAT = F / Pressure Gauge VG2 is active.
# HIERARCH ESO INS SENS96 STAT = F / Pressure Gauge VG3 is active.
# HIERARCH ESO INS SENS97 STAT = F / PSU Vacuum System Pump on/off.
# HIERARCH ESO INS SENS98 STAT = F / PSU Heater Status on/off.
# HIERARCH ESO INS SENS99 STAT = 8196 / Roughing Vacuum Pump Status.
# HIERARCH ESO INS SENSOR1 ID = 'sensor1 ' / Sensor device unique id.
# HIERARCH ESO INS SENSOR1 NAME = 'Siemens PLC LM band' / Sensor device common nam
# HIERARCH ESO INS SENSOR2 ID = 'sensor2 ' / Sensor device unique id.
# HIERARCH ESO INS SENSOR2 NAME = 'Siemens PLC N band' / Sensor device common name
# HIERARCH ESO INS SENSOR3 ID = 'sensor3 ' / Sensor device unique id.
# HIERARCH ESO INS SENSOR3 NAME = 'Siemens PLC WOB' / Sensor device common name.
# HIERARCH ESO INS SFL ENC = -90846 / [Enc] L&M Spatial Filter device absolute pos
# HIERARCH ESO INS SFL ID = '1.50    ' / L&M Spatial Filter device unique ID.
# HIERARCH ESO INS SFL NAME = '1.50    ' / L&M Spatial Filter device name.
# HIERARCH ESO INS SFL NO =    7 / L&M Spatial Filter device slot number.
# HIERARCH ESO INS SFL TYPE = 'NA      ' / L&M Spatial Filter device element type.
# HIERARCH ESO INS SFN ENC = -90855 / [Enc] N SFN device absolute position.
# HIERARCH ESO INS SFN ID = '2.00    ' / N SFN device unique ID.
# HIERARCH ESO INS SFN NAME = '2.00    ' / N SFN device name.
# HIERARCH ESO INS SFN NO =    7 / N SFN device slot number.
# HIERARCH ESO INS SFN TYPE = 'NA      ' / N SFN device element type.
# HIERARCH ESO INS SOS1 ENC = 207 / [Enc] Source Selector absolute position.
# HIERARCH ESO INS SOS1 ID = 'OUT     ' / Source Selector unique ID.
# HIERARCH ESO INS SOS1 NAME = 'OUT     ' / Source Selector name.
# HIERARCH ESO INS SOS1 NO =   1 / Source Selector slot number.
# HIERARCH ESO INS SOS1 TYPE = 'NA      ' / Source Selector type.
# HIERARCH ESO INS SOS2 ENC = 198 / [Enc] Source Selector absolute position.
# HIERARCH ESO INS SOS2 ID = 'OUT     ' / Source Selector unique ID.
# HIERARCH ESO INS SOS2 NAME = 'OUT     ' / Source Selector name.
# ...
# HIERARCH ESO ISS AT4 NAOMI WFSGEOM = '6x6     ' / WFS Geometry [6x6 or ACQ].
# HIERARCH ESO ISS AT4 NAOMI WFSRMS END = 0.039858 / WFS rms  ATi [um].
# HIERARCH ESO ISS AT4 NAOMI WFSRMS START = 0.038975 / WFS rms  ATi [um].
# HIERARCH ESO ISS AT4 NAOMI WFSSPOTSZ END = 1.899977 / WFS Spot size ATi [px].
# HIERARCH ESO ISS AT4 NAOMI WFSSPOTSZ START = 1.956306 / WFS Spot size ATi [px].
# HIERARCH ESO ISS AZ =    8.871 / Azimuth angles at start [deg].
# HIERARCH ESO ISS BASELINE = 'medium  ' / Interferometric Array.
# HIERARCH ESO ISS CHOP ST = 'F       ' / Chopping status.
# HIERARCH ESO ISS CONF A1L = 108.488553 / Static optical path length [m] arm 1.
# HIERARCH ESO ISS CONF A2L = 87.095073 / Static optical path length [m] arm 2.
# HIERARCH ESO ISS CONF A3L = 115.105 / Static optical path length [m] arm 3.
# HIERARCH ESO ISS CONF A4L = 139.903251 / Static optical path length [m] arm 4.
# HIERARCH ESO ISS CONF DL1 = 'DL4     ' / Delay line used in arm 1.
# HIERARCH ESO ISS CONF DL2 = 'DL2     ' / Delay line used in arm 2.
# HIERARCH ESO ISS CONF DL3 = 'DL1     ' / Delay line used in arm 3 .
# HIERARCH ESO ISS CONF DL4 = 'DL3     ' / Delay line used in arm 4.
# HIERARCH ESO ISS CONF INPUT1 = 1 / Primary lab input channel arm 1.
# HIERARCH ESO ISS CONF INPUT2 = 3 / Primary lab input channel arm 2.
# HIERARCH ESO ISS CONF INPUT3 = 5 / Primary lab input channel arm 3.
# HIERARCH ESO ISS CONF INPUT4 = 7 / Primary switchyard config. arm 4.
# HIERARCH ESO ISS CONF NTEL = 4 / Number of telescopes used.
# HIERARCH ESO ISS CONF STATION1 = 'K0      ' / Station of telescope arm 1.
# HIERARCH ESO ISS CONF STATION2 = 'G2      ' / Station of telescope arm 2.
# HIERARCH ESO ISS CONF STATION3 = 'D0      ' / Station of telescope arm 3.
# HIERARCH ESO ISS CONF STATION4 = 'J3      ' / Station of telescope arm 4.
# HIERARCH ESO ISS CONF SWYARD1 = 'compressed' / Primary switchyard config. arm 1.
# HIERARCH ESO ISS CONF SWYARD2 = 'compressed' / Primary switchyard config. arm 2.
# HIERARCH ESO ISS CONF SWYARD3 = 'compressed' / Primary switchyard config. arm 3.
# HIERARCH ESO ISS CONF SWYARD4 = 'compressed' / Primary switchyard config. arm 4.
# HIERARCH ESO ISS CONF T1NAME = 'AT1     ' / Telescope name arm 1.
# HIERARCH ESO ISS CONF T1X = -106.390772 / Telescope X coordinate [m] arm 1.
# HIERARCH ESO ISS CONF T1Y = 14.19113 / Telescope Y coordinate [m] arm 1.
# HIERARCH ESO ISS CONF T1Z = 4.553854 / Telescope Z coordinate [m] arm 1.
# HIERARCH ESO ISS CONF T2NAME = 'AT2     ' / Telescope name arm 2.
# HIERARCH ESO ISS CONF T2X = -38.069183 / Telescope X coordinate [m] arm 2.
# HIERARCH ESO ISS CONF T2Y = 12.300852 / Telescope Y coordinate [m] arm 2.
# HIERARCH ESO ISS CONF T2Z = 4.543747 / Telescope Z coordinate [m] arm 2.
# HIERARCH ESO ISS CONF T3NAME = 'AT3     ' / Telescope name arm 3.
# HIERARCH ESO ISS CONF T3X = -15.627957 / Telescope X coordinate [m] arm 3.
# HIERARCH ESO ISS CONF T3Y = 45.397348 / Telescope Y coordinate [m] arm 3.
# HIERARCH ESO ISS CONF T3Z = 4.5397 / Telescope Z coordinate [m] arm 3.
# HIERARCH ESO ISS CONF T4NAME = 'AT4     ' / Telescope name arm 4.
# HIERARCH ESO ISS CONF T4X = -80.635924 / Telescope X coordinate [m] arm 4.
# HIERARCH ESO ISS CONF T4Y = -36.168413 / Telescope Y coordinate [m] arm 4.
# HIERARCH ESO ISS CONF T4Z = 4.552136 / Telescope Z coordinate [m] arm 4.
# HIERARCH ESO ISS DATE = '2022-11-30T14:21:59.000' / Timestamp of last ISS build.
# HIERARCH ESO ISS DID = 'ESO-VLT-DIC.ISS' / Data dictionary name.
# HIERARCH ESO ISS FEED MODE = 'SINGLE_STS' / VLTI feed mode (TRANSPARENT,SINGLE_S
# HIERARCH ESO ISS GEOELEV = 2669. / VLTI ground site height above WGS84 [m].
# HIERARCH ESO ISS GEOLAT = -24.62743941 / VLTI site latitude (UV zero) [deg].
# HIERARCH ESO ISS GEOLON = -70.40498688 / VLTI site longitude (UV zero) [deg].
# HIERARCH ESO ISS IAS IRIS DIT = 1. / IRIS Detector Integration Time [s].
# HIERARCH ESO ISS IAS IRIS_GUID = 'OFF     ' / IRIS labguiding state (ON, OFF).
# HIERARCH ESO ISS IAS MIRR9 NAME = 'OUT     ' / ARAL IAS ALI slide position for T
# HIERARCH ESO ISS IAS OPTI10 NAME = 'PUP     ' / ARAL Iris Fly Eye and Telephoto
# HIERARCH ESO ISS IAS OPTI9 NAME = 'OUT     ' / ARAL Iris notch filter setting (I
# HIERARCH ESO ISS IAS SELECTED = 'IRIS    ' / Selected image alignment sensor (NO
# HIERARCH ESO ISS ID = 'v ISS   ' / ISS version string.
# HIERARCH ESO ISS M2POSZ AT1 = 0.107011 / Z position for M2 mirror of ATi [mm].
# HIERARCH ESO ISS M2POSZ AT2 = -0.189286 / Z position for M2 mirror of ATi [mm].
# HIERARCH ESO ISS M2POSZ AT3 = 0.135661 / Z position for M2 mirror of ATi [mm].
# HIERARCH ESO ISS M2POSZ AT4 = 0.114979 / Z position for M2 mirror of ATi [mm].
# HIERARCH ESO ISS MARCEL OPTI1 NAME = 'OUT     ' / ARAL MARCEL beam splitter A (O
# HIERARCH ESO ISS MARCEL OPTI2 NAME = 'OUT     ' / ARAL MARCEL beam splitter B (O
# HIERARCH ESO ISS MARCEL OPTI3 NAME = 'OUT     ' / ARAL MARCEL beam splitter C (O
# HIERARCH ESO ISS MARCEL OPTI4 NAME = 'OUT     ' / ARAL MARCEL beam splitter D (O
# HIERARCH ESO ISS MARCEL OPTI5 NAME = 'OUT     ' / ARAL MARCEL beam splitter E (O
# HIERARCH ESO ISS MARCEL OPTI6 NAME = 'OUT     ' / ARAL MARCEL beam splitter F (O
# HIERARCH ESO ISS OPER = 'I I Condor' / Name of VLTI operator.
# HIERARCH ESO ISS PARANG END = 19.201 / Parallactic angle at end [deg].
# HIERARCH ESO ISS PARANG START = 18.844 / Parallactic angle at start [deg].
# HIERARCH ESO ISS PBL12 END = 68.103 / Projected baseline T1 T2 at end [m].
# HIERARCH ESO ISS PBL12 START = 68.114 / Projected baseline T1 T2 at start [m].
# HIERARCH ESO ISS PBL13 END = 91.376 / Projected baseline T1 T3 at end [m].
# HIERARCH ESO ISS PBL13 START = 91.433 / Projected baseline T1 T3 at start [m].
# HIERARCH ESO ISS PBL14 END = 48.105 / Projected baseline T1 T4 at end [m].
# HIERARCH ESO ISS PBL14 START = 48.08 / Projected baseline T1 T4 at start [m].
# HIERARCH ESO ISS PBL23 END = 32.292 / Projected baseline T2 T3 at end [m].
# HIERARCH ESO ISS PBL23 START = 32.327 / Projected baseline T2 T3 at start [m].
# HIERARCH ESO ISS PBL24 END = 53.838 / Projected baseline T2 T4 at end [m].
# HIERARCH ESO ISS PBL24 START = 53.898 / Projected baseline T2 T4 at start [m].
# HIERARCH ESO ISS PBL34 END = 85.931 / Projected baseline T3 T4 at end [m].
# HIERARCH ESO ISS PBL34 START = 86.026 / Projected baseline T3 T4 at start [m].
# HIERARCH ESO ISS PBLA12 END = 283.5 / Projected baseline orientation angle T1 T2
# HIERARCH ESO ISS PBLA12 START = 283.3 / Projected baseline orientation angle T1
# HIERARCH ESO ISS PBLA13 END = 267.2 / Projected baseline orientation angle T1 T3
# HIERARCH ESO ISS PBLA13 START = 267. / Projected baseline orientation angle T1
# HIERARCH ESO ISS PBLA14 END = 335.321 / Projected baseline orientation angle T1
# HIERARCH ESO ISS PBLA14 START = 335.151 / Projected baseline orientation angle T
# HIERARCH ESO ISS PBLA23 END = 230.9 / Projected baseline orientation angle T2 T3
# HIERARCH ESO ISS PBLA23 START = 230.7 / Projected baseline orientation angle T2
# HIERARCH ESO ISS PBLA24 END = 58.949 / Projected baseline orientation angle T2 T
# HIERARCH ESO ISS PBLA24 START = 58.754 / Projected baseline orientation angle T2
# HIERARCH ESO ISS PBLA34 END = 55.931 / Projected baseline orientation angle T3 T
# HIERARCH ESO ISS PBLA34 START = 55.741 / Projected baseline orientation angle T3
# HIERARCH ESO ISS REF DEC = -641020.21 / Reference Delta as given by user.
# HIERARCH ESO ISS REF RA = 102852.57 / Reference Alpha as given by user.
# HIERARCH ESO ISS TEMP LAB1 = 15.39 / Temp in lab.
# HIERARCH ESO ISS TEMP TUN1 = 16.59 / Temp in tunnel west [C], duct A.
# HIERARCH ESO ISS TEMP TUN2 = 16.1 / Temp in tunnel centre [C], M16 west.
# HIERARCH ESO ISS TEMP TUN3 = 16.44 / Temp in tunnel centre [C], M16 east.
# HIERARCH ESO ISS TEMP TUN4 = 17.53 / Temp in tunnel east [C], duct L.
# HIERARCH ESO ISS TRAK STATUS = 'NORMAL  ' / Tracking status.
# HIERARCH ESO ISS VLTITYPE = 'snapshot' / Type of interferometric observations.
# HIERARCH ESO OCS DET2 IMGNAME = 'MATISSE_OBS_HISENS_N_STD_' / Data File Name.
# HIERARCH ESO SEQ OFFSET ALPHA = 0. / [mas] Off-axis total offset in RA
# HIERARCH ESO SEQ OFFSET DELTA = 0. / [mas] Off-axis total offset in DEC
# HIERARCH ESO SEQ TARG FLUX L = 166. / [Jy] L band flux in jansky
# HIERARCH ESO SEQ TARG FLUX N = 20.7 / [Jy] N band flux in jansky
# HIERARCH ESO SEQ TARG MAG K = 0.7 / [mag] K band magnitude
# HIERARCH ESO CFG BCD MODE = 'OUT-OUT '
# HIERARCH ESO QC DET2 TFSQR1 MEAN = 0.795324945455822
# HIERARCH ESO QC DET2 TFSQR2 MEAN = 0.861374379475817
# HIERARCH ESO QC DET2 TFSQR3 MEAN = 0.674789882599391
# HIERARCH ESO QC DET2 TFSQR4 MEAN = 0.554270201641604
# HIERARCH ESO QC DET2 TFSQR5 MEAN = 0.664681416334386
# HIERARCH ESO QC DET2 TFSQR6 MEAN = 0.464237111674901
# HIERARCH ESO QC DET2 TRANS IP1 = 6.16663647750566E-05
# HIERARCH ESO QC DET2 TRANS IP3 = 7.80249615419731E-05
# HIERARCH ESO QC DET2 TRANS IP5 = 7.52874815428906E-05
# HIERARCH ESO QC DET2 TRANS IP7 = 8.61711171659537E-05
# HIERARCH ESO QC TF AVG = 0.66911298953032
# HIERARCH ESO QC TF STDEV = 0.14704336577711
# HIERARCH ESO QC TF SNR = 4.55044663860978
# HIERARCH ESO QC DET2 VISSQR1 = 0.717353716127324
# HIERARCH ESO QC DET2 VISSQR1 SNR = 20.8002624316682
# HIERARCH ESO QC DET2 VISSQR2 = 0.808218404081913
# HIERARCH ESO QC DET2 VISSQR2 SNR = 10.9877552192383
# HIERARCH ESO QC DET2 VISSQR3 = 0.665253914491012
# HIERARCH ESO QC DET2 VISSQR3 SNR = 14.2803276491058
# HIERARCH ESO QC DET2 VISSQR4 = 0.53244215191859
# HIERARCH ESO QC DET2 VISSQR4 SNR = 14.983889556595
# HIERARCH ESO QC DET2 VISSQR5 = 0.592074005838654
# HIERARCH ESO QC DET2 VISSQR5 SNR = 12.6495075142166
# HIERARCH ESO QC DET2 VISSQR6 = 0.449971517941323
# HIERARCH ESO QC DET2 VISSQR6 SNR = 1.05137693544958
# HIERARCH ESO QC INS DISP = 'LOW     '
# HIERARCH ESO QC INS FILT = 'OPEN    '
# HIERARCH ESO QC INS POLARIZER = 'OPEN    '
# HIERARCH ESO QC INS PHOT SLIDER = 'INTER   '
# HIERARCH ESO QC INS SPAT FILTER = '2.00    '
# HIERARCH ESO QC INS FILT ENC = 2406
# HIERARCH ESO QC INS DISP ENC = -966942
# HIERARCH ESO QC DET1 NAME = '        '
# HIERARCH ESO QC DET2 NAME = 'MATISSE-N'
# HIERARCH ESO QC DET2 CPHASE1 = 0.952995166181913
# HIERARCH ESO QC DET2 CPHASE1 STDEV = 10.174666717134
# HIERARCH ESO QC DET2 CPHASE2 = -1.3900943398968
# HIERARCH ESO QC DET2 CPHASE2 STDEV = 12.2954084653811
# HIERARCH ESO QC DET2 CPHASE3 = -0.0606260311759449
# HIERARCH ESO QC DET2 CPHASE3 STDEV = 15.0709422185313
# HIERARCH ESO QC DET2 CPHASE4 = 3.185383984486
# HIERARCH ESO QC DET2 CPHASE4 STDEV = 14.760032729464
# HIERARCH ESO QC DET2 FLUX IP5 = 150.406842803955
# HIERARCH ESO QC DET2 RATIO IP5 = 0.250000000951095
# HIERARCH ESO QC DET2 FLUX JY IP5 = 0.00237358496025451
# HIERARCH ESO QC DET2 FLUX IP7 = 172.149810409546
# HIERARCH ESO QC DET2 RATIO IP7 = 0.28614025774222
# HIERARCH ESO QC DET2 FLUX JY IP7 = 0.00271671283886572
# HIERARCH ESO QC DET2 FLUX IP3 = 155.875689888
# HIERARCH ESO QC DET2 RATIO IP3 = 0.259090091207127
# HIERARCH ESO QC DET2 FLUX JY IP3 = 0.00245988936600247
# HIERARCH ESO QC DET2 FLUX IP1 = 123.1950258255
# HIERARCH ESO QC DET2 RATIO IP1 = 0.204769650099559
# HIERARCH ESO QC DET2 FLUX JY IP1 = 0.00194415263977527
# HIERARCH ESO QC VIS AVG = 0.627552285066469
# HIERARCH ESO QC VIS STDEV = 0.129588217843348
# HIERARCH ESO QC DET2 DPHASE1 = 2.21511175914971
# HIERARCH ESO QC DET2 DPHASE1 STDEV = 0.799626644427119
# HIERARCH ESO QC DET2 DPHASE2 = -0.836901042884905
# HIERARCH ESO QC DET2 DPHASE2 STDEV = 1.73530988729992
# HIERARCH ESO QC DET2 DPHASE3 = 0.57224172464501
# HIERARCH ESO QC DET2 DPHASE3 STDEV = 1.27538457788006
# HIERARCH ESO QC DET2 DPHASE4 = 2.4800822474444
# HIERARCH ESO QC DET2 DPHASE4 STDEV = 1.20275619482325
# HIERARCH ESO QC DET2 DPHASE5 = -0.318991961643585
# HIERARCH ESO QC DET2 DPHASE5 STDEV = 1.73291219429557
# HIERARCH ESO QC DET2 DPHASE6 = 1.58179018240653
# HIERARCH ESO QC DET2 DPHASE6 STDEV = 2.05266569764458
# HIERARCH ESO QC FLUX AVG = 150.40684223175
# HIERARCH ESO QC FLUX STDEV = 20.3563905772066
# HIERARCH ESO QC FLUX SNR = 7.38867932707894
# HIERARCH ESO QC TOT FLUX = 601.627368927002
# HIERARCH PRO DISP COEF0 = -41.4489597684005
# HIERARCH PRO DISP COEF1 = 0.15458488748618
# HIERARCH PRO DISP COEF2 = -0.000105493962982983
# HIERARCH PRO DISP COEF3 =   0.
# HIERARCH PRO DISP COEF4 =   0.
# HIERARCH PRO FRAME TARGET = 233
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CHECKSUM= '9UP9AUP62UP69UP6'   / HDU checksum updated 2023-01-31T10:40:20
# DATASUM = '         0'         / data unit checksum updated 2023-01-31T10:40:20

# %%
image_wavelength
wc=[]
for i in range(len(image_wavelength[:])):
    wc.append(image_wavelength[i][0])
#wc=np.flip(wc)

# %%
vis2c=[[0 for x in range(len(image_vis2[0][4]))] for y in range(6)]
for i in range(6):
    for j in range(len(image_vis2[0][4])):
        #print(j)
        vis2c[i][j]=image_vis2[i][4][j]

# %%
fluxc0=[]
for i in range(len(image_flux[0][4])):
    fluxc0.append(image_flux[0][4][i])
    
fluxc1=[]
for i in range(len(image_flux[1][4])):
    fluxc1.append(image_flux[1][4][i])
    
fluxc2=[]
for i in range(len(image_flux[2][4])):
    fluxc2.append(image_flux[2][4][i])
    
fluxc3=[]
for i in range(len(image_flux[3][4])):
    fluxc3.append(image_flux[3][4][i])

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.plot(np.array(wc)*1e+6, fluxc0)
ax.plot(np.array(wc)*1e+6, fluxc1)
ax.plot(np.array(wc)*1e+6, fluxc2)
ax.plot(np.array(wc)*1e+6, fluxc3)
#ax.set_ylim(0, 1.1)
ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
#fig.savefig("cal-l-reduced-1.7.6.png")
# Out:
# Text(0, 0.5, 'Flux')

# %%
image_file = get_pkg_data_filename('/home/ariggonz/Desktop/MATISSE-data-model-comp/V602-Car/SCI_V602-Car_TARGET_CAL_INT_2023-01-20T07_40_27.3634_4-N-BAND.fits')
image_wavelength=fits.getdata(image_file, ext=3)
image_flux=fits.getdata(image_file, ext=7)
image_vis2=fits.getdata(image_file, ext=4)
w=[]
for i in range(len(image_wavelength[:])):
    w.append(image_wavelength[i][0])
vis2=[[0 for x in range(len(image_vis2[0][4]))] for y in range(6)]
for i in range(6):
    for j in range(len(image_vis2[0][4])):
        #print(j)
        vis2[i][j]=image_vis2[i][4][j]
flux0=[]
for i in range(len(image_flux[0][4])):
    flux0.append(image_flux[0][4][i])
flux1=[]
for i in range(len(image_flux[1][4])):
    flux1.append(image_flux[1][4][i])
flux2=[]
for i in range(len(image_flux[2][4])):
    flux2.append(image_flux[2][4][i])
flux3=[]
for i in range(len(image_flux[3][4])):
    flux3.append(image_flux[3][4][i])
    

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux1)/np.mean(flux1), label="data")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
#fig.savefig("cal-l-reduced-1.7.6.png")

# %%
#flux number 0
#adjust for the telluric lines (check the shift)
#using https://www.eso.org/observing/etc/bin/gen/form?INS.MODE=swspectr+INS.NAME=SKYCALC
minim2=9.576#mum
#minim1=2.37137 #mum
#get minimum in data
cond_min=(np.array(w)*1e+6>minim2-0.05)&(np.array(w)*1e+6<minim2+0.05)
min_data0=np.array(w)[cond_min][np.argmax(np.array(flux0)[cond_min])]
print(min_data0)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))

ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data0*1e+6, c="green")

ax.plot(np.array(w)*1e+6, np.array(flux0)/np.mean(flux0), label="data")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux0)[cond_min]/np.mean(flux0), label="data2")

ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")
ax.legend()


#shift
delta_w0=(-minim2*1e-6+min_data0)
print("shift: ", delta_w0*1e+6)
wnew0=np.array(w)-delta_w0
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))

ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data0*1e+6, c="green")

ax.plot(np.array(w)*1e+6, np.array(flux0)/np.mean(flux0), label="data")
ax.plot(np.array(wnew0)*1e+6, np.array(flux0)/np.mean(flux0), label="data shifted")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux0)[cond_min]/np.mean(flux0), label="data2")

ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
# Out:
# 9.616317e-06
# shift:  0.04031667451001758

# %%
#the same for calibrator 0
#flux number 0
#adjust for the telluric lines (check the shift)
#using https://www.eso.org/observing/etc/bin/gen/form?INS.MODE=swspectr+INS.NAME=SKYCALC
#minim2=3.903 #mum
#minim1=2.37137 #mum
#get minimum in data
cond_minc=(np.array(wc)*1e+6>minim2-0.05)&(np.array(wc)*1e+6<minim2+0.05)
min_datac0=np.array(wc)[cond_minc][np.argmax(np.array(fluxc0)[cond_minc])]
print(min_datac0)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac0*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc0)/np.mean(fluxc0), label="data")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc0)[cond_min]/np.mean(fluxc0), label="data2")
#ax.set_xlim(0.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_wc0=(-minim2*1e-6+min_datac0)
wnewc0=np.array(wc)-delta_w0
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac0*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc0)/np.mean(fluxc0), label="data")
ax.plot(np.array(wnewc0)*1e+6, np.array(fluxc0)/np.mean(fluxc0), label="data shifted")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc0)[cond_min]/np.mean(fluxc0), label="data2")
#ax.set_xlim(0.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
# Out:
# 9.567753e-06

# %%
#flux 1
min_data1=np.array(w)[cond_min][np.argmax(np.array(flux1)[cond_min])]
print(min_data1)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data1*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux1)/np.mean(flux1), label="data")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux1)[cond_min]/np.mean(flux1), label="data2")
#ax.set_xlim(1.85, 1.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_w1=(-minim2*1e-6+min_data1)
wnew1=np.array(w)-delta_w1
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data1*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux1)/np.mean(flux1), label="data")
ax.plot(np.array(wnew1)*1e+6, np.array(flux1)/np.mean(flux1), label="data shifted")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux1)[cond_min]/np.mean(flux1), label="data2")
#ax.set_xlim(1.85, 1.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()

min_datac1=np.array(wc)[cond_minc][np.argmax(np.array(fluxc1)[cond_minc])]
print(min_datac1)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac1*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="data")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc1)[cond_min]/np.mean(fluxc1), label="data2")
#ax.set_xlim(1.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_wc1=(-minim2*1e-6+min_datac1)
wnewc1=np.array(wc)-delta_w1
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac1*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="data")
ax.plot(np.array(wnewc1)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="data shifted")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc1)[cond_min]/np.mean(fluxc1), label="data2")
#ax.set_xlim(1.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
# Out:
# 9.616317e-06
# 9.567753e-06

# %%
#flux 2
min_data2=np.array(w)[cond_min][np.argmax(np.array(flux2)[cond_min])]
print(min_data2)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data2*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux2)/np.mean(flux2), label="data")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux2)[cond_min]/np.mean(flux2), label="data2")
#ax.set_xlim(2.85, 2.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_w2=(-minim2*1e-6+min_data2)
wnew2=np.array(w)-delta_w2
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data2*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux2)/np.mean(flux2), label="data")
ax.plot(np.array(wnew2)*1e+6, np.array(flux2)/np.mean(flux2), label="data shifted")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux2)[cond_min]/np.mean(flux2), label="data2")
#ax.set_xlim(2.85, 2.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()

min_datac2=np.array(wc)[cond_minc][np.argmax(np.array(fluxc2)[cond_minc])]
print(min_datac2)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac2*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc2)/np.mean(fluxc2), label="data")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc2)[cond_min]/np.mean(fluxc2), label="data2")
#ax.set_xlim(2.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_wc2=(-minim2*1e-6+min_datac2)
wnewc2=np.array(wc)-delta_w2
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac2*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc2)/np.mean(fluxc2), label="data")
ax.plot(np.array(wnewc2)*1e+6, np.array(fluxc2)/np.mean(fluxc2), label="data shifted")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc2)[cond_min]/np.mean(fluxc2), label="data2")
#ax.set_xlim(2.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
# Out:
# 9.567753e-06
# 9.567753e-06

# %%
#flux 3
min_data3=np.array(w)[cond_min][np.argmax(np.array(flux3)[cond_min])]
print(min_data3)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data3*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux3)/np.mean(flux3), label="data")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux3)[cond_min]/np.mean(flux3), label="data2")
#ax.set_xlim(3.85, 3.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_w3=(-minim2*1e-6+min_data3)
wnew3=np.array(w)-delta_w3
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_data3*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(w)*1e+6, np.array(flux3)/np.mean(flux3), label="data")
ax.plot(np.array(wnew3)*1e+6, np.array(flux3)/np.mean(flux3), label="data shifted")
ax.plot(np.array(w)[cond_min]*1e+6, np.array(flux3)[cond_min]/np.mean(flux3), label="data2")
#ax.set_xlim(3.85, 3.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()

min_datac3=np.array(wc)[cond_minc][np.argmax(np.array(fluxc3)[cond_minc])]
print(min_datac3)

fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac3*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc3)/np.mean(fluxc3), label="data")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc3)[cond_min]/np.mean(fluxc3), label="data2")
#ax.set_xlim(3.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()


#shift
delta_wc3=(-minim2*1e-6+min_datac3)
wnewc3=np.array(wc)-delta_w3
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))
#for i in range(len(flux)):
#    ax.plot(np.array(w)*1e+6, vis2[i])
ax.axvline(x=minim2, c="red")
ax.axvline(x=min_datac3*1e+6, c="green")
#ax.plot(np.array(wc)*1e+6, np.array(fluxc1)/np.mean(fluxc1), label="calib")
ax.plot(np.array(wc)*1e+6, np.array(fluxc3)/np.mean(fluxc3), label="data")
ax.plot(np.array(wnewc3)*1e+6, np.array(fluxc3)/np.mean(fluxc3), label="data shifted")
ax.plot(np.array(wc)[cond_min]*1e+6, np.array(fluxc3)[cond_min]/np.mean(fluxc3), label="data2")
#ax.set_xlim(3.85, 4.1)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
# Out:
# 9.567753e-06
# 9.616317e-06

# %%
# get MARCS of calibrator
#Calibrator -> HD 163917 Teff>4900 K (so 5000), K0III, 3Msun [Z]=0, R=14Rsun, logg= 3, http://www.openexoplanetcatalogue.com/planet/nu%20Oph%20b/

# %%
marcs_flux=pd.read_table("/home/ariggonz/Desktop/MATISSE-data-model-comp/MARCS-models/s3800_g+1.0_m1.0_t02_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.flx", header=None)
m_flux=np.flip(marcs_flux[0])
marcs_w=pd.read_table("/home/ariggonz/Desktop/MATISSE-data-model-comp/MARCS-models/flx_wavelengths.vac", header=None)
m_w=np.flip(marcs_w[0])

# %%
#Reduce the MARCS model to the MATISSE resolution
len(wc)
all_step=[]
for i in range(len(wc)-1):
    print((wc[i]-wc[i+1])*1e+10) #step 
    all_step.append((wc[i]-wc[i+1])*1e+10)
# Out:
# -553.1455826712772
# -551.0446499101818
# -548.9255272550508
# -546.8245944939554
# -544.7145667858422
# -542.5954441307113
# -540.4945113696158
# -538.3844836615026
# -536.2653610063717
# -534.1644282452762
# -532.054400537163
# -529.9443728290498
# -527.8252501739189
# -525.7243174128234
# -523.6142897047102
# -521.504261996597
# -519.3851393414661
# -517.2842065803707
# -515.1741788722575
# -513.0641511641443
# -510.9541234560311
# -508.8440957479179
# -506.7340680398047
# -504.6240403316915
# -502.5140126235783
# -500.4039849154651
# -498.2939572073519
# -496.18392949923873
# -494.07390179112554
# -491.96387408301234
# -489.85384637489915
# -487.74381866678596
# -485.63379095867276
# -483.52376325055957
# -481.4137355424464
# -479.3037078343332
# -477.19368012622
# -475.0927473651245
# -472.9736247099936
# -470.8635970018804
# -468.7535692937672
# -466.643541585654
# -464.54260882455856
# -462.42348616942763
# -460.31345846131444
# -458.20343075320125
# -456.1024979921058
# -453.98337533697486
# -451.87334762886167
# -449.7724148677662
# -447.6532922126353
# -445.5523594515398
# -443.4332367964089
# -441.3232090882957
# -439.22227632720023
# -437.1031536720693
# -435.00222091097385
# -432.8830982558429
# -430.78216549474746
# -428.66304283961654
# -426.5621100785211
# -424.44298742339015
# -422.3420546622947
# -420.2320269541815
# -418.11290429905057
# -416.0119715379551
# -413.8928488828242
# -411.7919161217287
# -409.6818884136155
# -407.5627657584846
# -405.46183299738914
# -403.35180528927594
# -401.24177758116275
# -399.1226549260318
# -397.02172216493636
# -394.91169445682317
# -392.80166674871
# -390.6916390405968
# -388.57251638546586
# -386.4715836243704
# -384.3615559162572
# -382.251528208144
# -380.1415005000308
# -378.0314727919176
# -375.92144508380443
# -373.81141737569124
# -371.70138966757804
# -369.59136195946485
# -367.48133425135165
# -365.37130654323846
# -363.26127883512527
# -361.1512511270121
# -359.0412234188989
# -356.9311957107857
# -354.8211680026725
# -352.7111402945593
# -350.6011125864461
# -348.4910848783329
# -346.3810571702197
# -344.28012440912426
# -342.16100175399333
# -340.05097404588014
# -337.94094633776695
# -335.83091862965375
# -333.7299858685583
# -331.61086321342736
# -329.50083550531417
# -327.3999027442187
# -325.2807800890878
# -323.1707523809746
# -321.0698196198791
# -318.9506969647482
# -316.840669256635
# -314.73973649553955
# -312.6206138404086
# -310.51968107931316
# -308.40055842418224
# -306.2996256630868
# -304.18050300795585
# -302.0795702468604

# %%
x0=np.linspace(min(wnewc0)*1e+10, max(wnewc0)*1e+10, len(wnewc0)+1, endpoint=True)
len(x0)

cond0=(np.array(m_w)*1e-4<max(wnewc0)*1e+6)&(np.array(m_w)*1e-4>min(wnewc0)*1e+6)
cond0

digitized = np.digitize(m_w[cond0], x0)
bin_means_w0 = np.flip([m_w[cond0][digitized == i].mean() for i in range(1, len(x0))])
bin_means_w0

bin_means_f0 = np.flip([m_flux[cond0][digitized == i].mean() for i in range(1, len(x0))])
len(bin_means_f0)
# Out:
# 121

# %%
x1=np.linspace(min(wnewc1)*1e+10, max(wnewc1)*1e+10, len(wnewc1)+1, endpoint=True)
len(x1)

cond1=(np.array(m_w)*1e-4<max(wnewc1)*1e+6)&(np.array(m_w)*1e-4>min(wnewc1)*1e+6)
cond1

digitized = np.digitize(m_w[cond1], x1)
bin_means_w1 = np.flip([m_w[cond1][digitized == i].mean() for i in range(1, len(x1))])
bin_means_w1

bin_means_f1 = np.flip([m_flux[cond1][digitized == i].mean() for i in range(1, len(x1))])
len(bin_means_f1)
# Out:
# 121

# %%
x2=np.linspace(min(wnewc2)*1e+10, max(wnewc2)*1e+10, len(wnewc2)+1, endpoint=True)
len(x2)

cond2=(np.array(m_w)*1e-4<max(wnewc2)*1e+6)&(np.array(m_w)*1e-4>min(wnewc2)*1e+6)
cond2

digitized = np.digitize(m_w[cond2], x2)
bin_means_w2 = np.flip([m_w[cond2][digitized == i].mean() for i in range(1, len(x2))])
bin_means_w2

bin_means_f2 = np.flip([m_flux[cond2][digitized == i].mean() for i in range(1, len(x2))])
len(bin_means_f2)
# Out:
# 121

# %%
x3=np.linspace(min(wnewc3)*1e+10, max(wnewc3)*1e+10, len(wnewc3)+1, endpoint=True)
len(x3)

cond3=(np.array(m_w)*1e-4<max(wnewc3)*1e+6)&(np.array(m_w)*1e-4>min(wnewc3)*1e+6)
cond3

digitized = np.digitize(m_w[cond3], x3)
bin_means_w3 = np.flip([m_w[cond3][digitized == i].mean() for i in range(1, len(x3))])
bin_means_w3

bin_means_f3 = np.flip([m_flux[cond3][digitized == i].mean() for i in range(1, len(x3))])
len(bin_means_f3)
# Out:
# 121

# %%
norm_marcs0=np.array(bin_means_f0)/np.mean(bin_means_f0)
norm_marcs1=np.array(bin_means_f1)/np.mean(bin_means_f1)
norm_marcs2=np.array(bin_means_f2)/np.mean(bin_means_f2)
norm_marcs3=np.array(bin_means_f3)/np.mean(bin_means_f3)

# %%
norm_flux0=np.array(flux0)/np.mean(flux0)
norm_flux1=np.array(flux1)/np.mean(flux1)
norm_flux2=np.array(flux2)/np.mean(flux2)
norm_flux3=np.array(flux3)/np.mean(flux3)

# %%
norm_fluxc0=np.array(fluxc0)/np.mean(fluxc0)
norm_fluxc1=np.array(fluxc1)/np.mean(fluxc1)
norm_fluxc2=np.array(fluxc2)/np.mean(fluxc2)
norm_fluxc3=np.array(fluxc3)/np.mean(fluxc3)

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))


ax.plot(np.array(bin_means_w2)*1e-4, (np.array(norm_flux2)/np.array(norm_fluxc2))*np.array(norm_marcs2), label="flux 2")
ax.plot(np.array(bin_means_w1)*1e-4, (np.array(norm_flux1)/np.array(norm_fluxc1))*np.array(norm_marcs1), label="flux 1")
ax.plot(np.array(bin_means_w3)*1e-4, (np.array(norm_flux3)/np.array(norm_fluxc3))*np.array(norm_marcs3), label="flux 3")
ax.plot(np.array(bin_means_w0)*1e-4, (np.array(norm_flux0)/np.array(norm_fluxc0))*np.array(norm_marcs0), label="flux 0")
#ax.set_xlim(3.88, 4.1)
ax.set_ylim(0, 3)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$")
ax.set_ylabel(r"Flux")#$|V|^{2}$
ax.legend()
fig.savefig("flux-MATISSE-V602-Car-N.png")

# %%
mean_f0=(np.array(norm_flux0)/np.array(norm_fluxc0))*np.array(norm_marcs0)
mean_f1=(np.array(norm_flux1)/np.array(norm_fluxc1))*np.array(norm_marcs1)
mean_f2=(np.array(norm_flux2)/np.array(norm_fluxc2))*np.array(norm_marcs2)
mean_f3=(np.array(norm_flux3)/np.array(norm_fluxc3))*np.array(norm_marcs3)

# %%
#do the mean
mean_flux=[]
for i in range(len(norm_flux2)):
    
    mean_flux_e=np.mean([mean_f0[i],
                  mean_f1[i],
                  mean_f2[i],
                  mean_f3[i]])
    mean_flux.append(mean_flux_e)

# %%
#This is the final, calibrated, normalized and mean flux for the N band of the SCI
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot((111))

ax.plot(np.array(bin_means_w2)*1e-4, mean_flux, c="k", label="V602 Car")
#ax.set_xlim(3.88, 4.1)
ax.set_ylim(0, 2)
ax.set_xlim(8, 11.75)
#ax.set_title("CAL L reduced")
ax.set_xlabel(r"wavelength $(\mu m)$", fontsize=15)
ax.set_ylabel(r"Flux", fontsize=15)#$|V|^{2}$
ax.tick_params(labelsize=15)
ax.legend(loc=1,prop={'size':15})
fig.savefig("flux-MATISSE-V602-Car-N-mean.png")

# %%
w_bin_means=np.array(bin_means_w2)*1e-4
# Out:
# [13.02057216 12.9783251  12.93589179 12.89327482 12.85079817 12.80846148
#  12.76626425 12.72388815 12.68133557 12.63892521 12.59665669 12.55421592
#  12.51160505 12.46913889 12.42681693 12.38463851 12.34229496 12.29978843
#  12.25742834 12.21490897 12.17253665 12.13031175 12.08793095 12.04539719
#  12.00301276 11.96077792 11.91809568 11.87556546 11.83318735 11.79066552
#  11.7482965  11.70607975 11.66372328 11.62122935 11.57889022 11.53641712
#  11.49381231 11.45136482 11.40907417 11.36665563 11.32439451 11.28200894
#  11.23950052 11.19715263 11.15468526 11.11237894 11.06995654 11.02742017
#  10.98504726 10.94283724 10.900517   10.85808883 10.8155556  10.77291949
#  10.73045145 10.68815078 10.64575094 10.60325403 10.56092683 10.51850576
#  10.47599302 10.43365217 10.3914823  10.34922445 10.30662308 10.26419669
#  10.22194533 10.17935888 10.13694953 10.09471726 10.05215826 10.00977834
#   9.96732852  9.92481003  9.88247325  9.84007089  9.7976057   9.7550798
#   9.71273841  9.67033922  9.6278842   9.58561563  9.54329426  9.50092195
#   9.45850161  9.41603504  9.37352492  9.33120643  9.28884732  9.24644879
#   9.20401422  9.16154483  9.11927177  9.07673989  9.03418038  8.9918204
#   8.9494355   8.90702756  8.8645991   8.82215201  8.77990826  8.73764842
#   8.69515729  8.6526563   8.61036303  8.56806249  8.52554348  8.48302321
#   8.44071498  8.39840805  8.35589534  8.31338978  8.27110051  8.22861523
#   8.186143    8.14389045  8.10145079  8.05903065  8.01663242  7.97425772
#   7.93190895]

# %%
#Save a file with the final calibrated flux of the N band
file =open("mean-flux-V602-Car-N.txt", "w")
file.write("w,flux"+"\n")
for i in range(len(mean_flux)):
    file.write(str(w_bin_means[i])+","+str(mean_flux[i])+"\n")
file.close()
